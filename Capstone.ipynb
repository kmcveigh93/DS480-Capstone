# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Cleaning the Dataset

# %%
#uploading dataset to file
csv_file_path = 

weather =
